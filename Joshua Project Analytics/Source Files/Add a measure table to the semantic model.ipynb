# %% [markdown]
# # Add a measure table to the semantic model

# %%
data = [(1, 'MeasureTable')]
columns = ['ID', 'Col1']
# Out:
# StatementMeta(, dc107f71-4783-4b77-a01f-a8fdbe8c911f, 3, Finished, Available, Finished)

# %%
measure_df = spark.createDataFrame(data, columns)
measure_df.show()
spark.sql("DROP TABLE IF EXISTS MeasureTable")
measure_df.write.format("delta").saveAsTable('MeasureTable')
# Out:
# StatementMeta(, dc107f71-4783-4b77-a01f-a8fdbe8c911f, 4, Finished, Available, Finished)
# +---+------------+
# | ID|        Col1|
# +---+------------+
# |  1|MeasureTable|
# +---+------------+
